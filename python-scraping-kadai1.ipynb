# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://news.yahoo.co.jp/articles/a2b2e28fb5c361c29e37c5bfc07fd4c7098634f4'
response=requests.get(url)
soup=BeautifulSoup(response.text, 'html.parser')

# %%
tilte_element=soup.select_one('#uamods >div >div >p')

# %%
print(tilte_element)
# Out:
# <p class="sc-fIYNhG cbJyZa yjSlinkDirectlink highLightSearchTarget">Laurie Chen　Yew Lun Tian　Guy Faulconbridge
#
# [北京／モスクワ　１９日　ロイター] - ロシアのプーチン大統領が５月に中国を訪問し、習近平国家主席と会談する予定であることが分かった。関係筋５人が明らかにした。大統領選挙で勝利したプーチン氏が新たな任期に入ってから初めての外遊になりそうだ。
#
# 関係筋の１人は匿名を条件に「プーチンが中国を訪問する」とロイターに明らかにし、他の４人の関係筋が個別に詳細を確認した。
#
# 訪中はおそらく５月後半になり、予定される習氏の欧州訪問の前に行われる見通しという。
#
# ロシア大統領府はコメントを差し控えた。中国外務省からはコメントを得られていない。
#
# プーチン氏の正式な大統領就任式は５月７日ごろに予定されている。
#
# 習氏は昨年３月、国家主席として異例の３期目入り直後にロシアを訪問した。</p>

# %%
tilte_element=tilte_element.text

# %%
tilte_element
# Out:
# 'Laurie Chen\u3000Yew Lun Tian\u3000Guy Faulconbridge\n\n[北京／モスクワ\u3000１９日\u3000ロイター] - ロシアのプーチン大統領が５月に中国を訪問し、習近平国家主席と会談する予定であることが分かった。関係筋５人が明らかにした。大統領選挙で勝利したプーチン氏が新たな任期に入ってから初めての外遊になりそうだ。\n\n関係筋の１人は匿名を条件に「プーチンが中国を訪問する」とロイターに明らかにし、他の４人の関係筋が個別に詳細を確認した。\n\n訪中はおそらく５月後半になり、予定される習氏の欧州訪問の前に行われる見通しという。\n\nロシア大統領府はコメントを差し控えた。中国外務省からはコメントを得られていない。\n\nプーチン氏の正式な大統領就任式は５月７日ごろに予定されている。\n\n習氏は昨年３月、国家主席として異例の３期目入り直後にロシアを訪問した。'
